# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/Rhythms_off_Algorithms/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the library with the iris dataset
from sklearn.datasets import load_iris

# Load scikit's random forest classifier library
from sklearn.ensemble import RandomForestClassifier

# Load pandas
import pandas as pd

# Load numpy
import numpy as np

# Set random seed
np.random.seed(0)

# %%
# Create an object called iris with the iris data
dataset = pd.read_csv('/content/data.csv')

# View the top 5 rows
dataset.head()
# Out:
#   Subject Sleep Stage  ...  Spectral Edge_Gamma_O2  PeakF_Gamma_O2
# 0   SN002           W  ...                      50              50
# 1   SN002           W  ...                      50              50
# 2   SN002           W  ...                      50              50
# 3   SN002           W  ...                      50              50
# 4   SN002           W  ...                      50              50
#
# [5 rows x 78 columns]

# %%
print("Are you sure? (y)")
i=input()
if i=="y":
  dataset.drop(columns=dataset.columns[2], 
        axis=1, 
        inplace=True)
# Out:
# Are you sure? (y)
# y

# %%
x = dataset.iloc[:, 0:4].values
y = dataset.iloc[:, 4].values
print(x)
# Out:
# [['SN002' 'W' 0 9]
#  ['SN002' 'W' 0 10]
#  ['SN002' 'W' 0 10]
#  ...
#  ['SN060' 'N2' 0 8]
#  ['SN060' 'N2' 0 8]
#  ['SN060' 'N2' 0 8]]
